# %%
import pandas as pd
import utils
import plotly.graph_objects as go

# %%
pair ="EUR_USD"
granularity = "H1"

# %%
df = pd.read_csv(utils.get_his_data_filename(pair,granularity))

# %%
df_plot = df
df_plot
# Out:
#      Unnamed: 0                            time  volume    mid_o    mid_h  \
# 0             0  2021-11-02T05:00:00.000000000Z    1149  1.16038  1.16074
# 1             1  2021-11-02T05:00:00.000000000Z    1149  1.16038  1.16074
# 2             2  2021-11-02T05:00:00.000000000Z    1149  1.16038  1.16074
# 3             3  2021-11-02T05:00:00.000000000Z    1149  1.16038  1.16074
# 4             4  2021-11-02T05:00:00.000000000Z    1149  1.16038  1.16074
# ..          ...                             ...     ...      ...      ...
# 103         103  2021-11-02T13:00:00.000000000Z    5416  1.16070  1.16077
# 104         104  2021-11-02T13:00:00.000000000Z    5416  1.16070  1.16077
# 105         105  2021-11-02T13:00:00.000000000Z    5416  1.16070  1.16077
# 106         106  2021-11-02T13:00:00.000000000Z    5416  1.16070  1.16077
# 107         107  2021-11-02T13:00:00.000000000Z    5416  1.16070  1.16077
#
#        mid_l    mid_c    bid_o    bid_h    bid_l    bid_c    ask_o    ask_h  \
# 0    1.16021  1.16073  1.16032  1.16067  1.16014  1.16065  1.16045  1.16082
# 1    1.16021  1.16073  1.16032  1.16067  1.16014  1.16065  1.16045  1.16082
# 2    1.16021  1.16073  1.16032  1.16067  1.16014  1.16065  1.16045  1.16082
# 3    1.16021  1.16073  1.16032  1.16067  1.16014  1.16065  1.16045  1.16082
# 4    1.16021  1.16073  1.16032  1.16067  1.16014  1.16065  1.16045  1.16082
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 103  1.15890  1.15913  1.16064  1.16070  1.15882  1.15906  1.16077  1.16084
# 104  1.15890  1.15913  1.16064  1.16070  1.15882  1.15906  1.16077  1.16084
# 105  1.15890  1.15913  1.16064  1.16070  1.15882  1.15906  1.16077  1.16084
# 106  1.15890  1.15913  1.16064  1.16070  1.15882  1.15906  1.16077  1.16084
# 107  1.15890  1.15913  1.16064  1.16070  1.15882  1.15906  1.16077  1.16084
#
#        ask_l    ask_c
# 0    1.16028  1.16081
# 1    1.16028  1.16081
# 2    1.16028  1.16081
# 3    1.16028  1.16081
# 4    1.16028  1.16081
# ..       ...      ...
# 103  1.15897  1.15920
# 104  1.15897  1.15920
# 105  1.15897  1.15920
# 106  1.15897  1.15920
# 107  1.15897  1.15920
#
# [108 rows x 15 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df_plot.time, open = df_plot.mid_o, high = df_plot.mid_h, low = df_plot.mid_l, close = df_plot.mid_c,
))
fig.update_layout(width=1000,height=600,
margin= dict(l=10,r=10,b=10,t=10) )
fig.update_xaxes(rangeslider=dict(visible=False))
fig.show()
